# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **<font size="3">Artist Layer</font>**

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FC

# %%
from matplotlib.figure import Figure

# %%
fig = Figure()
canvas = FC(fig)
import numpy as np
x = np.random.randn(10000)
ax = fig.add_subplot(111)
ax.hist(x,100)
ax.set_title('Title')
fig.savefig('ABC.png')

# %% [markdown]
# **<font size="3">Scripting Layer</font>**

# %%
x= np.random.randn(10000)
plt.hist(x,100)
plt.title('Title')
plt.show()

# %%
sizes = [10,90]
labels=['cat1','cat2']
colors=['red','yellow']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Win percentage batting second")
plt.show()

# %%
ind =[10,20,30,40,50]
labels=['A','B','C','D','E']
width=2.9
fig, ax = plt.subplots()
rects = ax.bar(ind, labels, width=width, color='y')
ax.set_ylabel("Count")
ax.set_title("Top player of the match awardees")
plt.show()

# %%
A = [10,20,30,3,11,43]
B = [1,2,3,4,5]

plt.scatter(x,y,color="green")
plt.show()
